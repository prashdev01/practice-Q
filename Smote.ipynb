# %% [markdown]
# # **SMOTE (Synthetic minority oversampling technique)**
# # SMOTE is a technique which is used in machine learning for handling imbalanced dataset where the minority class has the significantly lower the instance than the majority class.

# %%
from sklearn.datasets import make_classification

# %%
#  x independent feature
#  y dependent feature

x,y=make_classification(n_samples=1000,n_features=2,n_redundant=0,n_clusters_per_class=1,weights=[0.90],random_state=1)

# %%
import pandas as pd
df1 = pd.DataFrame(x,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
final_df = pd.concat([df1,df2],axis=1)

# %%
final_df.head()
# Out:
#          f1        f2  target
# 0  1.536830 -1.398694       1
# 1  1.551108  1.810329       0
# 2  1.293619  1.010946       0
# 3  1.119889  1.632518       0
# 4  1.042356  1.121529       0

# %%
final_df['target'].value_counts()
# Out:
# 0    894
# 1    106
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %%
# %pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\shiv\appdata\local\programs\python\python311\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\shiv\appdata\local\programs\python\python311\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\shiv\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\shiv\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.9.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\shiv\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.1.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\shiv\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shiv\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn->imblearn) (3.1.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
x,y =oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
x.shape
# Out:
# (1788, 2)

# %%
len(y[y==0])
# Out:
# 894

# %%
len(y[y==1])
# Out:
# 894

# %%
df1=pd.DataFrame(x,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
oversample_df = pd.concat([df1,df2],axis=1)

# %%
plt.scatter(oversample_df['f1'],oversample_df['f2'],c=oversample_df['target'])
